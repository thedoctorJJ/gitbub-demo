# %% [markdown]
# <a href="https://colab.research.google.com/github/thedoctorJJ/gitbub-demo/blob/master/Single_Audit_Auditor_FAC_Scraper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests beautifulsoup4 pandas openpyxl

from google.colab import drive
drive.mount('/content/drive')

import os
output_dir = "/content/drive/My Drive/FAC_Scraper"
os.makedirs(output_dir, exist_ok=True)

import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime
import time

class FACSearchScraper:
    def __init__(self, output_dir="/content/drive/My Drive/FAC_Scraper"):
        self.base_url = "https://app.fac.gov"
        self.search_url = "https://app.fac.gov/dissemination/search/"
        self.session = requests.Session()
        self.headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36',
            'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
        }
        self.output_dir = output_dir

    def get_csrf_token(self):
        """Get CSRF token from the search page"""
        response = self.session.get(self.search_url, headers=self.headers)
        soup = BeautifulSoup(response.text, 'html.parser')
        return soup.find('input', {'name': 'csrfmiddlewaretoken'})['value']

    def get_audit_details(self, url):
        """Extract auditor details from an audit summary page"""
        print(f"Fetching details from: {url}")
        try:
            full_url = self.base_url + url if not url.startswith('http') else url
            response = self.session.get(full_url, headers=self.headers)
            soup = BeautifulSoup(response.text, 'html.parser')

            # Find the auditor information section
            auditor_section = soup.find(lambda tag: tag.name == 'h2' and 'Auditor' in tag.text)
            if not auditor_section:
                return None

            # Get the table following the Auditor heading
            table = auditor_section.find_next('table')
            if not table:
                return None

            # Extract data from the table
            data = {}
            rows = table.find_all('tr')
            for row in rows:
                cells = row.find_all('td')
                for cell in cells:
                    # Look for specific fields
                    if strong := cell.find('strong'):
                        field = strong.text.strip().replace(':', '').strip()
                        value = cell.text.replace(strong.text, '').strip()
                        if field == 'Contact Name':
                            data['Auditor_Name'] = value
                        elif field == 'Contact title':
                            data['Title'] = value
                        elif field == 'Email':
                            data['Email'] = value
                        elif field == 'Phone':
                            data['Phone'] = value
                        elif field == 'City and state':
                            city_state = value.split(',')
                            if len(city_state) == 2:
                                data['City'] = city_state[0].strip()
                                data['State'] = city_state[1].strip()

            # Get auditee name from the page title
            auditee_name = soup.find('p', class_='margin-0 text-bold')
            if auditee_name:
                data['Auditee_Name'] = auditee_name.text.strip()

            return data

        except Exception as e:
            print(f"Error getting audit details: {e}")
            return None

    def search_audits(self, state='NY', audit_years=['2023', '2024'], limit=130):
        """Perform the search and get results with pagination"""
        csrf_token = self.get_csrf_token()
        print(f"Got CSRF token, submitting search...")

        results = []
        page = 1

        while len(results) < limit:
            print(f"\nProcessing page {page}...")

            form_data = {
                'csrfmiddlewaretoken': csrf_token,
                'audit_year': audit_years,
                'auditee_state': state,
                'page': str(page)
            }

            response = self.session.post(
                self.search_url,
                data=form_data,
                headers={**self.headers, 'Referer': self.search_url}
            )

            soup = BeautifulSoup(response.text, 'html.parser')

            # Find all summary links on this page
            summary_links = []
            for link in soup.find_all('a', href=True):
                if '/dissemination/summary/' in link['href']:
                    summary_links.append(link['href'])

            if not summary_links:
                print("No more results found on this page")
                break

            print(f"Found {len(summary_links)} audit reports on this page")

            # Process each summary page
            for i, link in enumerate(summary_links, 1):
                if len(results) >= limit:
                    break

                print(f"\nProcessing audit {len(results) + 1} of {limit}")
                auditor_info = self.get_audit_details(link)
                if auditor_info:
                    auditor_info['Report_ID'] = link.split('/')[-1]
                    results.append(auditor_info)
                    print(f"Found auditor: {auditor_info.get('Auditor_Name', 'Unknown')}")
                time.sleep(1)  # Be nice to the server

            page += 1

        print(f"\nCompleted processing {len(results)} audit reports")
        return results

    # Update just the save_to_excel method in Cell 2
    def save_to_excel(self, results, state='NY'):
        """Save results to Excel with numbered index"""
        if results:
            timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
            filename = os.path.join(self.output_dir, f'auditor_contacts_{state}_{timestamp}.xlsx')

            df = pd.DataFrame(results)

            # Add numbered index starting from 1
            df.insert(0, 'Number', range(1, len(df) + 1))

            # Reorder columns with Number first
            columns = ['Number', 'Report_ID', 'Auditee_Name', 'Auditor_Name', 'Title',
                      'Email', 'Phone', 'City', 'State']
            df = df.reindex(columns=columns)

            df.to_excel(filename, index=False)
            print(f"\nResults saved to {filename}")
            return df
        else:
            print("\nNo results to save")
            return None

# Run the scraper
scraper = FACSearchScraper()
results = scraper.search_audits(state='NY', audit_years=['2023', '2024'], limit=130)
df = scraper.save_to_excel(results)

if df is not None:
    print("\nFirst few results:")
    display(df.head())
    print(f"\nTotal audits found: {len(df)}")
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.12.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (3.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.8.30)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Got CSRF token, submitting search...
#
# Processing page 1...
# Found 30 audit reports on this page
#
# Processing audit 1 of 130
# Fetching details from: /dissemination/summary/2023-06-GSAFAC-0000061985
# Found auditor: John Eusanio
#
# Processing audit 2 of 130
# Fetching details from: /dissemination/summary/2023-12-GSAFAC-0000056856
# Found auditor: Nicole Overbaugh
#
# Processing audit 3 of 130
# Fetching details from: /dissemination/summary/2023-12-GSAFAC-0000064457
# Found auditor: Luis Carlos Rivera
#
# Processing audit 4 of 130
# Fetching details from: /dissemination/summary/2024-03-GSAFAC-0000056347
# Found auditor: Cole Monroe
#
# Processing audit 5 of 130
# Fetching details from: /dissemination/summary/2024-04-GSAFAC-0000064230
# Found auditor: TAMI RADINSKY
#
# Processing audit 6 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000057315
# Found auditor: ROBERT DANIELE
#
# Processing audit 7 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000061524
# Found auditor: Duane Shoen
#
# Processing audit 8 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000061533
# Found auditor: TRICIA LUCAS
#
# Processing audit 9 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000061618
# Found auditor: EDWARD J. BYSIEK, CPA
#
# Processing audit 10 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000062639
# Found auditor: SETH HENNARD
#
# Processing audit 11 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000062845
# Found auditor: ADAM COLE
#
# Processing audit 12 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000062904
# Found auditor: Adam Cole
#
# Processing audit 13 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000063148
# Found auditor: Adam Cole
#
# Processing audit 14 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000063743
# Found auditor: Diana Miller
#
# Processing audit 15 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000064487
# Found auditor: Shannon Mannese, CPA
#
# Processing audit 16 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000064841
# Found auditor: JENNIFER CAPICCHIONI
#
# Processing audit 17 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000064972
# Found auditor: Jeanne Beutner
#
# Processing audit 18 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000065354
# Found auditor: LOUANN LAURITO-BAHGAT, CPA
#
# Processing audit 19 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000061491
# Found auditor: Duane Shoen
#
# Processing audit 20 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000063865
# Found auditor: Alex Zhang
#
# Processing audit 21 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000064951
# Found auditor: Jeanne Beutner
#
# Processing audit 22 of 130
# Fetching details from: /dissemination/summary/2023-12-GSAFAC-0000056613
# Found auditor: JOSEPH ARNONE
#
# Processing audit 23 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000064711
# Found auditor: Keeley Hines
#
# Processing audit 24 of 130
# Fetching details from: /dissemination/summary/2023-05-GSAFAC-0000052330
# Found auditor: MELISSA SZOT
#
# Processing audit 25 of 130
# Fetching details from: /dissemination/summary/2023-07-GSAFAC-0000052996
# Found auditor: JOHN COSTILOW, CPA
#
# Processing audit 26 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000061356
# Found auditor: Evan Cleveland
#
# Processing audit 27 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000062100
# Found auditor: Kylene Fitsik
#
# Processing audit 28 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000063609
# Found auditor: thomas zuber
#
# Processing audit 29 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000064254
# Found auditor: Shawn Gillon
#
# Processing audit 30 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000065084
# Found auditor: GUS SALIBA
#
# Processing page 2...
# Found 30 audit reports on this page
#
# Processing audit 31 of 130
# Fetching details from: /dissemination/summary/2023-08-GSAFAC-0000064814
# Found auditor: Abraham Kahan
#
# Processing audit 32 of 130
# Fetching details from: /dissemination/summary/2023-12-GSAFAC-0000063103
# Found auditor: WARREN RUPPEL, CPA
#
# Processing audit 33 of 130
# Fetching details from: /dissemination/summary/2023-12-GSAFAC-0000064857
# Found auditor: Jonathan Gibbs
#
# Processing audit 34 of 130
# Fetching details from: /dissemination/summary/2024-03-GSAFAC-0000064413
# Found auditor: ANDREW FOX, CPA
#
# Processing audit 35 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000061467
# Found auditor: MARK LEVY
#
# Processing audit 36 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000061895
# Found auditor: NICOLE CHUBBUCK
#
# Processing audit 37 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000062029
# Found auditor: LEONARD CARISSIMO
#
# Processing audit 38 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000062085
# Found auditor: Stephen Bailey
#
# Processing audit 39 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000064090
# Found auditor: Mark Ciaralli
#
# Processing audit 40 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000064388
# Found auditor: MICHAEL ROSSI
#
# Processing audit 41 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000064640
# Found auditor: JILL THAISZ
#
# Processing audit 42 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000064809
# Found auditor: WILLIAM TRAINOR
#
# Processing audit 43 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000064843
# Found auditor: Samantha Hillman
#
# Processing audit 44 of 130
# Fetching details from: /dissemination/summary/2023-12-GSAFAC-0000058246
# Found auditor: David Tellier
#
# Processing audit 45 of 130
# Fetching details from: /dissemination/summary/2023-12-GSAFAC-0000064265
# Found auditor: Kenneth McGivney
#
# Processing audit 46 of 130
# Fetching details from: /dissemination/summary/2023-12-GSAFAC-0000064345
# Found auditor: Israel Lowinger
#
# Processing audit 47 of 130
# Fetching details from: /dissemination/summary/2023-12-GSAFAC-0000064593
# Found auditor: Duane Shoen
#
# Processing audit 48 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000052517
# Found auditor: STEWART GRUBMAN
#
# Processing audit 49 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000052692
# Found auditor: STEWART GRUBMAN
#
# Processing audit 50 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000053174
# Found auditor: STEWART GRUBMAN
#
# Processing audit 51 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000061016
# Found auditor: DANIEL KROL
#
# Processing audit 52 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000061059
# Found auditor: THOMAS SMITH, CPA
#
# Processing audit 53 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000061129
# Found auditor: MICHAEL ROSSI
#
# Processing audit 54 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000061911
# Found auditor: DANIEL KROL
#
# Processing audit 55 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000062352
# Found auditor: Richard Ferguson
#
# Processing audit 56 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000062398
# Found auditor: Jaimie Galante
#
# Processing audit 57 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000063000
# Found auditor: SARAH HOPKINS
#
# Processing audit 58 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000063605
# Found auditor: Gregg Evans
#
# Processing audit 59 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000063889
# Found auditor: John Tafilowski, CPA
#
# Processing audit 60 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000064079
# Found auditor: SARAH HOPKINS
#
# Processing page 3...
# Found 30 audit reports on this page
#
# Processing audit 61 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000064097
# Found auditor: Alexandria Battaglia, CPA
#
# Processing audit 62 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000064139
# Found auditor: AMY PEDRICK
#
# Processing audit 63 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000064207
# Found auditor: Alan Walther
#
# Processing audit 64 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000064213
# Found auditor: Alan Walther
#
# Processing audit 65 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000064374
# Found auditor: AMY PEDRICK
#
# Processing audit 66 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000064399
# Found auditor: DAVID URBAN, CPA
#
# Processing audit 67 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000064553
# Found auditor: Jason Mayausky
#
# Processing audit 68 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000064630
# Found auditor: Jaimie Galante
#
# Processing audit 69 of 130
# Fetching details from: /dissemination/summary/2023-12-GSAFAC-0000060411
# Found auditor: AMY PEDRICK
#
# Processing audit 70 of 130
# Fetching details from: /dissemination/summary/2024-03-GSAFAC-0000064191
# Found auditor: ANDREW FOX, CPA
#
# Processing audit 71 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000054326
# Found auditor: DAVID V. DITANNA, CPA
#
# Processing audit 72 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000060741
# Found auditor: ALEXANDRIA BATTAGLIA, CPA
#
# Processing audit 73 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000060933
# Found auditor: LEONARD CARISSIMO
#
# Processing audit 74 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000061023
# Found auditor: MICHAEL ROSSI
#
# Processing audit 75 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000061084
# Found auditor: MICHAEL ROSSI
#
# Processing audit 76 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000061338
# Found auditor: David Tellier
#
# Processing audit 77 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000061413
# Found auditor: Christopher Angotta
#
# Processing audit 78 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000061419
# Found auditor: David Tellier
#
# Processing audit 79 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000061620
# Found auditor: EDWARD J. BYSIEK, CPA
#
# Processing audit 80 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000061768
# Found auditor: Laurie Podvin
#
# Processing audit 81 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000063597
# Found auditor: thomas zuber
#
# Processing audit 82 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000064073
# Found auditor: Gregg Evans
#
# Processing audit 83 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000064383
# Found auditor: MICHAEL ROSSI
#
# Processing audit 84 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000064384
# Found auditor: MICHAEL ROSSI
#
# Processing audit 85 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000064386
# Found auditor: MICHAEL ROSSI
#
# Processing audit 86 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000064415
# Found auditor: JILL THAISZ
#
# Processing audit 87 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000064454
# Found auditor: STEPHEN WOOD
#
# Processing audit 88 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000064485
# Found auditor: DAVID BROWNELL
#
# Processing audit 89 of 130
# Fetching details from: /dissemination/summary/2023-06-GSAFAC-0000062280
# Found auditor: Sofia Blair
#
# Processing audit 90 of 130
# Fetching details from: /dissemination/summary/2023-12-GSAFAC-0000058432
# Found auditor: Justin Reid
#
# Processing page 4...
# Found 30 audit reports on this page
#
# Processing audit 91 of 130
# Fetching details from: /dissemination/summary/2023-12-GSAFAC-0000062527
# Found auditor: Heather R. Lewis, CPA
#
# Processing audit 92 of 130
# Fetching details from: /dissemination/summary/2024-03-GSAFAC-0000062253
# Found auditor: DOUGLAS ZIMMERMAN, CPA
#
# Processing audit 93 of 130
# Fetching details from: /dissemination/summary/2024-05-GSAFAC-0000059643
# Found auditor: MELISSA SZOT
#
# Processing audit 94 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000058280
# Found auditor: EDWARD J. BYSIEK, CPA
#
# Processing audit 95 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000061076
# Found auditor: Duane Shoen
#
# Processing audit 96 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000061100
# Found auditor: JILL THAISZ
#
# Processing audit 97 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000061597
# Found auditor: Shannon Mannese, CPA
#
# Processing audit 98 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000062045
# Found auditor: Joseph Heroux
#
# Processing audit 99 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000062267
# Found auditor: Christopher J. Healy, CPA, CGFM
#
# Processing audit 100 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000062367
# Found auditor: BRENT JENSEN, CPA
#
# Processing audit 101 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000062590
# Found auditor: Robert Stackel
#
# Processing audit 102 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000062613
# Found auditor: Erica Proctor
#
# Processing audit 103 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000062908
# Found auditor: BEN OWENS
#
# Processing audit 104 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000063065
# Found auditor: Heather Lewis
#
# Processing audit 105 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000063874
# Found auditor: John Tafilowski, CPA
#
# Processing audit 106 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000062125
# Found auditor: Alan Walther
#
# Processing audit 107 of 130
# Fetching details from: /dissemination/summary/2023-12-GSAFAC-0000062475
# Found auditor: BRENT T. NAPOLEON, CPA
#
# Processing audit 108 of 130
# Fetching details from: /dissemination/summary/2023-12-GSAFAC-0000063273
# Found auditor: Duane Shoen
#
# Processing audit 109 of 130
# Fetching details from: /dissemination/summary/2023-12-GSAFAC-0000063982
# Found auditor: TYLER SASS
#
# Processing audit 110 of 130
# Fetching details from: /dissemination/summary/2024-03-GSAFAC-0000063585
# Found auditor: MICHAEL GUYDER
#
# Processing audit 111 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000053012
# Found auditor: GUS SALIBA
#
# Processing audit 112 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000054389
# Found auditor: DAVID V. DITANNA, CPA
#
# Processing audit 113 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000059902
# Found auditor: MICHAEL ROSSI
#
# Processing audit 114 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000061175
# Found auditor: David Tellier
#
# Processing audit 115 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000061450
# Found auditor: Christopher Angotta
#
# Processing audit 116 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000062071
# Found auditor: Alan Walther
#
# Processing audit 117 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000062093
# Found auditor: Alan Walther
#
# Processing audit 118 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000062194
# Found auditor: thomas zuber
#
# Processing audit 119 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000062935
# Found auditor: BEN OWENS
#
# Processing audit 120 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000063146
# Found auditor: KELLY FRANK
#
# Processing page 5...
# Found 30 audit reports on this page
#
# Processing audit 121 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000063562
# Found auditor: Christopher M. Zera, CPA
#
# Processing audit 122 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000063999
# Found auditor: John Tafilowski, CPA
#
# Processing audit 123 of 130
# Fetching details from: /dissemination/summary/2023-09-GSAFAC-0000056120
# Found auditor: Perry Dinter
#
# Processing audit 124 of 130
# Fetching details from: /dissemination/summary/2024-01-GSAFAC-0000051358
# Found auditor: Nicholas C. Rivera, CPA, FHFMA, CHFP
#
# Processing audit 125 of 130
# Fetching details from: /dissemination/summary/2024-01-GSAFAC-0000063962
# Found auditor: Mr. Aron E. Muller
#
# Processing audit 126 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000057838
# Found auditor: SCOTT OLING
#
# Processing audit 127 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000059738
# Found auditor: MELISSA SZOT
#
# Processing audit 128 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000060969
# Found auditor: LEONARD CARISSIMO
#
# Processing audit 129 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000061021
# Found auditor: Evan Cleveland
#
# Processing audit 130 of 130
# Fetching details from: /dissemination/summary/2024-06-GSAFAC-0000061061
# Found auditor: THOMAS SMITH, CPA
#
# Completed processing 130 audit reports
#
# Results saved to /content/drive/My Drive/FAC_Scraper/auditor_contacts_NY_20241113_034822.xlsx
#
# First few results:
#    Number                  Report_ID  \
# 0       1  2023-06-GSAFAC-0000061985
# 1       2  2023-12-GSAFAC-0000056856
# 2       3  2023-12-GSAFAC-0000064457
# 3       4  2024-03-GSAFAC-0000056347
# 4       5  2024-04-GSAFAC-0000064230
#
#                                   Auditee_Name        Auditor_Name  \
# 0          Community Development Project, Inc.        John Eusanio
# 1       National Young Farmers Coalition, Inc.    Nicole Overbaugh
# 2                    AFTER HOURS PROJECT, INC.  Luis Carlos Rivera
# 3  Village of North Syracuse Housing Authority         Cole Monroe
# 4           AMERICAN JEWISH WORLD SERVICE, INC       TAMI RADINSKY
#
#            Title                         Email       Phone      City State
# 0        Partner  jeusanio@citrincooperman.com  2126971000  New York    NY
# 1      Principal         noverbaugh@uhy-us.com  5187199349    Hudson    NY
# 2        Partner             luis@cpatrust.com  8456383113  New City    NY
# 3      Principal              cmonroe@smco.cpa  6155453153  Franklin    TN
# 4  AUDIT PARTNER       TAMI.RADINSKY@US.GT.COM  6468258431  NEW YORK    NY
# Total audits found: 130
